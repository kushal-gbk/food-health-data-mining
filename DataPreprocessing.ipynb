# %% [markdown]
# # Data Preprocessing

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Read Dataset

# %%
df = pd.read_csv("ehresp_2014.csv")
df.head()
# Out:
#          tucaseid  tulineno  eeincome1      erbmi  erhhch  erincome  erspemch  \
# 0  20140101140007         1         -2  33.200001       1        -1        -1
# 1  20140101140011         1          1  22.700001       3         1        -1
# 2  20140101140028         1          2  49.400002       3         5        -1
# 3  20140101140063         1         -2  -1.000000       3        -1        -1
# 4  20140101140168         1          2  31.000000       3         5        -1
#
#    ertpreat  ertseat  ethgt    ...      eumeat  eumilk  euprpmel  eusoda  \
# 0        30        2      0    ...           1       2         1      -1
# 1        45       14      0    ...           1       2         1      -1
# 2        60        0      0    ...          -1      -1         2       2
# 3         0        0      0    ...           2       2         1       1
# 4        65        0      0    ...           1       2         1       2
#
#    eustores  eustreason  eutherm  euwgt  euwic  exincome1
# 0         2           1        2    170      1          2
# 1         1           2        2    128      2          0
# 2        -1          -1       -1    270      2         12
# 3         2           6       -1     -2      2          2
# 4         1           1        2    210      1          0
#
# [5 rows x 37 columns]

# %% [markdown]
# ## Filter Columns

# %%
df_new = df[['erbmi','ertpreat','eudrink','eueat','euexercise','eufastfd','eufdsit','euprpmel','eusoda','eugenhth']]
df_new.to_csv('intermediate_data.csv')
df_new.head()
# Out:
#        erbmi  ertpreat  eudrink  eueat  euexercise  eufastfd  eufdsit  \
# 0  33.200001        30        2      1           2         2        1
# 1  22.700001        45        2      1           2         1        1
# 2  49.400002        60        1      2           2         2        1
# 3  -1.000000         0        1      2           2         2        1
# 4  31.000000        65        1      2           1         2        1
#
#    euprpmel  eusoda  eugenhth
# 0         1      -1         1
# 1         1      -1         2
# 2         2       2         5
# 3         1       1         2
# 4         1       2         4

# %% [markdown]
# ## Drop NaN rows

# %%
df_new = pd.read_csv('intermediate_data.csv',na_values=['-1','-2','-3'])
df_new = df_new.dropna()
df_new.head()
# Out:
#    Unnamed: 0      erbmi  ertpreat  eudrink  eueat  euexercise  eufastfd  \
# 2           2  49.400002        60      1.0    2.0         2.0       2.0
# 4           4  31.000000        65      1.0    2.0         1.0       2.0
# 5           5  30.700001        20      1.0    1.0         1.0       1.0
# 6           6  33.299999        30      1.0    1.0         2.0       1.0
# 9           9  28.299999        80      1.0    2.0         2.0       1.0
#
#    eufdsit  euprpmel  eusoda  eugenhth
# 2      1.0       2.0     2.0       5.0
# 4      1.0       1.0     2.0       4.0
# 5      1.0       2.0     1.0       3.0
# 6      1.0       3.0     2.0       2.0
# 9      1.0       1.0     1.0       1.0

# %% [markdown]
# ## Codify BMI

# %%
# 1 - Underweight 2 - Normal  3 - Overweight
def codify_bmi(x):
    if(x < 18.5):
        return 1
    elif(x < 25):
        return 2
    else:
        return 3

# %%
df_new['codified_bmi'] = df_new['erbmi'].apply(codify_bmi)
df_new.head()
# Out:
#    Unnamed: 0      erbmi  ertpreat  eudrink  eueat  euexercise  eufastfd  \
# 2           2  49.400002        60      1.0    2.0         2.0       2.0
# 4           4  31.000000        65      1.0    2.0         1.0       2.0
# 5           5  30.700001        20      1.0    1.0         1.0       1.0
# 6           6  33.299999        30      1.0    1.0         2.0       1.0
# 9           9  28.299999        80      1.0    2.0         2.0       1.0
#
#    eufdsit  euprpmel  eusoda  eugenhth  codified_bmi
# 2      1.0       2.0     2.0       5.0             3
# 4      1.0       1.0     2.0       4.0             3
# 5      1.0       2.0     1.0       3.0             3
# 6      1.0       3.0     2.0       2.0             3
# 9      1.0       1.0     1.0       1.0             3

# %% [markdown]
# ## Change Health Codes

# %%
# Excellent,Very Good,Good health to 1
# Fair,Poor health to 0
def codify_gen_health(x):
    if(x==1):
        return 1
    elif(x==2):
        return 1
    elif(x==3):
        return 1
    elif(x==4):
        return 2
    elif(x==5):
        return 2
    else:
        return 2

# %%
df_new['codified_health'] = df_new['eugenhth'].apply(codify_gen_health)
df_new.head()
# Out:
#    Unnamed: 0      erbmi  ertpreat  eudrink  eueat  euexercise  eufastfd  \
# 2           2  49.400002        60      1.0    2.0         2.0       2.0
# 4           4  31.000000        65      1.0    2.0         1.0       2.0
# 5           5  30.700001        20      1.0    1.0         1.0       1.0
# 6           6  33.299999        30      1.0    1.0         2.0       1.0
# 9           9  28.299999        80      1.0    2.0         2.0       1.0
#
#    eufdsit  euprpmel  eusoda  eugenhth  codified_bmi  codified_health
# 2      1.0       2.0     2.0       5.0             3                2
# 4      1.0       1.0     2.0       4.0             3                2
# 5      1.0       2.0     1.0       3.0             3                1
# 6      1.0       3.0     2.0       2.0             3                1
# 9      1.0       1.0     1.0       1.0             3                1

# %% [markdown]
# ## Export to new CSV

# %%
df_new.to_csv('dataset_preprocessed.csv',index=False)
